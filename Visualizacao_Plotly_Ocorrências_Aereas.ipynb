# %% [markdown]
# <a href="https://colab.research.google.com/github/gisele-mgs/especializacacin/blob/main/Visualizacao_Plotly_Ocorr%C3%AAncias_Aereas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly_express

# %% [markdown]
# 1) Neste exercícos usaremos  dados que descrevem ocorrências aéreas na aviação brasileira ocorridas entre 2006 e 2015. Só para informação, os dados foram obtidos [aqui](https://dados.gov.br/dados/conjuntos-dados/ocorrencias-aeronauticas-da-aviacao-civil-brasileira). Carregue os dados de ocorrências aéreas disponibilizados no classroom. Inspecione algumas linhas para entender de maneira geral as colunas nos dados.

# %% [markdown]
# 2)Vamos agora estudar o comportamento temporal do número de ocorrências aéreas. Faremos isso de diferentes maneiras. Faça três gráficos:
# * Um gráfico de linha um que mostra o número de ocorrências aéreas ao longo dos anos;
# * Um gráfico de barras que mostra o número de ocorrências aéreas em cada mês no período dos dados;
# * Um gráfico de barras do número de ocorrências por estação do ano. Use o seguinte critério:
#   - Meses 12,1,2: Verão
#   - Meses 3,4,5: Outono
#   - Meses 6,7,8: Inverno
#   - Meses 9,10,11: Primavera
#
#   Sempre coloque labels e títulos nos seus gráficos.

# %% [markdown]
# 3) Faça um gráfico de pizza para mostrar o percentual da classificação das ocorrências.

# %% [markdown]
# 4) Faça um mapa do número de acidentes de vôos partindo de cada estado.

# %% [markdown]
# 5) Faça um scatterplot onde cada ponto é um ano, a posição x é a quantidade de ocorrências e o y é o  número de fatalidades. Use o parâmetro hover_data para mostrar o ano correspondente ao passar ao mouse sobre os pontos. Você consegue observar algum padrão neste gráfico?
